# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('matchcounts.csv')
df = df.sort_values('wbmatch')
print(df)
# Out:
#     wbmatch  counts
# 0       0.0     595
# 5       1.0     148
# 3       2.0      58
# 6       3.0      37
# 1       4.0      30
# 7       5.0      22
# 17      6.0      24
# 2       7.0      14
# 10      8.0      15
# 14      9.0      12
# 16     10.0       8
# 12     11.0      12
# 20     12.0       6
# 19     13.0       3
# 8      14.0      12
# 4      15.0       7
# 15     16.0       7
# 18     17.0       5
# 13     18.0       9
# 11     19.0      13
# 9      20.0       8

# %%
ax = df.plot.bar(x='wbmatch', y='counts')

# %%
df2 = pd.read_csv('hist.csv')
print(df2)
# Out:
#          fit
# 0     0.1665
# 1     0.1137
# 2     0.1286
# 3     0.2945
# 4     0.0506
# ...      ...
# 1040  0.4293
# 1041  0.0827
# 1042  1.4242
# 1043  0.2360
# 1044  0.0000
#
# [1045 rows x 1 columns]

# %%
ax = df2.plot.hist(bins=20)
